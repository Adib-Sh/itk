# %%
from ECStripLengthNoiseComparison import ECStripLengthNoiseComparison

# %%
subtypes = []
allBarrelSubtypes = ["SSX", "SSY", "LSX", "LSY"]
with open("../Helpers/subtypes.txt", 'r') as f:
    allECSubtypes = f.read().split(',')
allSubtypes = []
allSubtypes.extend(allECSubtypes)
allSubtypes.extend(allBarrelSubtypes)
subtypes = allSubtypes

# %%
for subtype in allSubtypes:
    ECStripLengthNoiseComparison(subtype, variable="innse", verbose=False)
# Out:
# Number of R0H0 hybrids: 6
# Subtype R0H0 has strip lengths 1.900 2.400
# Number of R0H1 hybrids: 6
# Subtype R0H1 has strip lengths 3.200 2.900
# Number of R1H0 hybrids: 10
# Subtype R1H0 has strip lengths 1.810 2.710
# Number of R1H1 hybrids: 7
# Subtype R1H1 has strip lengths 1.510 2.410
# Number of R2H0 hybrids: 24
# Subtype R2H0 has strip lengths 3.080 3.080
# Number of R3H0 hybrids: 3
# Subtype R3H0 has strip lengths 2.620 3.220
# Number of R3H1 hybrids: 3
# Subtype R3H1 has strip lengths 2.620 3.220
# Number of R3H2 hybrids: 3
# Subtype R3H2 has strip lengths 2.620 3.220
# /home/kaastran/Documents/aqt/itk-strip-module-analysis/analysis/ECStripLengthNoiseComparison/ECStripLengthNoiseComparison.py:122: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
# Number of R3H3 hybrids: 3
# Subtype R3H3 has strip lengths 2.620 3.220
# Number of R4H0 hybrids: 10
# Subtype R4H0 has strip lengths 5.460 5.460
# Number of R4H1 hybrids: 10
# Subtype R4H1 has strip lengths 5.460 5.460
# Number of R5H0 hybrids: 4
# Subtype R5H0 has strip lengths 4.020 6.020
# Number of R5H1 hybrids: 4
# Subtype R5H1 has strip lengths 4.020 6.020
# Number of SSX hybrids: 9
#
# Number of SSX hybrids: 9
# Subtype SSX has strip lengths 2.416 2.416
# Number of SSY hybrids: 8
#
# Number of SSY hybrids: 8
# Subtype SSY has strip lengths 2.416 2.416
# Number of LSX hybrids: 12
#
# Number of LSX hybrids: 12
# Subtype LSX has strip lengths 4.835 4.835
# Number of LSY hybrids: 0
#
# WARNING: No hybrids for subtype LSY

# %%
ECStripLengthNoiseComparison(subtypes, variable="innse", verbose=False,
                             figsize=(12, 8), showHist=False, showComp=True,
                             streams=[1])
# Out:
# Number of SSX hybrids: 9
# Number of SSY hybrids: 8
# Number of LSX hybrids: 12
# Number of LSY hybrids: 0
#
# Number of LSX hybrids: 12
# Subtype LSX has strip lengths 4.835 4.835
#
# WARNING: No hybrids for subtype LSY
#
# Number of R0H0 hybrids: 6
# Subtype R0H0 has strip lengths 1.900 2.400
#
# Number of R0H1 hybrids: 6
# Subtype R0H1 has strip lengths 3.200 2.900
#
# Number of R1H0 hybrids: 10
# Subtype R1H0 has strip lengths 1.810 2.710
#
# Number of R1H1 hybrids: 7
# Subtype R1H1 has strip lengths 1.510 2.410
#
# Number of R2H0 hybrids: 24
# Subtype R2H0 has strip lengths 3.080 3.080
#
# Number of R3H0 hybrids: 3
# Subtype R3H0 has strip lengths 2.620 3.220
#
# Number of R3H1 hybrids: 3
# Subtype R3H1 has strip lengths 2.620 3.220
#
# Number of R3H2 hybrids: 3
# Subtype R3H2 has strip lengths 2.620 3.220
#
# Number of R3H3 hybrids: 3
# Subtype R3H3 has strip lengths 2.620 3.220
#
# Number of R4H0 hybrids: 10
# Subtype R4H0 has strip lengths 5.460 5.460
#
# Number of R4H1 hybrids: 10
# Subtype R4H1 has strip lengths 5.460 5.460
#
# Number of R5H0 hybrids: 4
# Subtype R5H0 has strip lengths 4.020 6.020
#
# Number of R5H1 hybrids: 4
# Subtype R5H1 has strip lengths 4.020 6.020
#
# Number of SSX hybrids: 9
# Subtype SSX has strip lengths 2.416 2.416
#
# Number of SSY hybrids: 8
# Subtype SSY has strip lengths 2.416 2.416
# No mean value for subtype LSY stream away
# No mean value for subtype R3H2 stream away
# No mean value for subtype R3H3 stream away
# Fit parameters; slope: 100.34114177864271
# intercept: 390.63234511387805

# %%
# Out:
# /home/kaastran/Documents/aqt/itk-strip-module-analysis/analysis/ECStripLengthNoiseComparison

# %%
import json
import glob
import matplotlib.pyplot as plt
jsonPath = "../../data/"

# %%
jsons = []
files = glob.glob(jsonPath + "*.json")
for file in files:
    with open(file, 'r') as f:
        jsons.append(json.load(f))

# %%
noneJs = {}
okJs = {}
points = []
dateDict = {}
componentInfo = {}
R0H1count = 0
noneAddressList = []
addressList = []
for jsonNumber, js in enumerate(jsons):
    go = False
    itsdaqVersion = None
    addresses = None
    for d in js["properties"]:
        if d["code"] == "scan_info":
            if len(d["value"]["points"]) == 10:
                if js["components"][0]["type"]["code"] == "R0H1":
                    R0H1count += 1
                if js["components"][0]["testedAtStage"]["code"] == "ON_MODULE":
                    go = True
        if d["code"] == "system_info":
            itsdaqVersion = d["value"]["GIT commit date"][:10]
        if d["code"] == "det_info":
            addresses = d["value"]["Address"]
    
    if itsdaqVersion and addresses:
        noneAddress = False
        for address in addresses:
            if address is None:
                noneAddress = True
        if noneAddress:
            noneAddressList.append(itsdaqVersion)
            if itsdaqVersion in noneJs.keys():
                noneJs[itsdaqVersion].append((js, jsonNumber))
            else:
                noneJs[itsdaqVersion] = [(js, jsonNumber)]
        else:
            addressList.append(itsdaqVersion)
            if itsdaqVersion in okJs.keys():
                okJs[itsdaqVersion].append((js, jsonNumber))
            else:
                okJs[itsdaqVersion] = [(js, jsonNumber)]
    
    if go:
        testDate = js["date"].split("T")[0]
        points.append((testDate, itsdaqVersion))
        
        if testDate in dateDict.keys():
            dateDict[testDate].append(itsdaqVersion)
        else:
            dateDict[testDate] = [itsdaqVersion]
        component = js["components"][0]
        sn = component["serialNumber"]
        subtype = component["type"]["code"]
        
        
        if sn in componentInfo.keys():
            componentInfo[sn]["count"] += 1
        else:
            componentInfo[sn] = {"count" : 1,
                                 "subtype" : subtype}
            for result in js["results"]:
                componentInfo[sn][result["code"]] = result["value"]
                
points.sort(key=lambda x: x[0])
testDates = list(set([point[0] for point in points]))
sizes = {}
for date in testDates:
    sizes[date] = len(dateDict[date])*25

# %%
fig = plt.figure(figsize=(8, 4))
ax = plt.gca()
ax.scatter([point[0] for point in points], [point[1] for point in points], s=[sizes[point[0]] for point in points])
xticklabels = ax.get_xticklabels()
ax.set_xticklabels(xticklabels, rotation = 90);
plt.xlabel("Test date")
plt.ylabel("ITSDAQ commit date")
# Out:
# /tmp/ipykernel_9084/3944766853.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels, rotation = 90);
# Text(0, 0.5, 'ITSDAQ commit date')

# %%
okSubtypes = []
noneSubtypes = []
for itsdaqVersion in okJs:
        for js, jsNumber in okJs[itsdaqVersion]:
            subtype = js["components"][0]["type"]["code"]
            okSubtypes.append(subtype)
            if subtype == 'R0H1':
                print(jsNumber, end=" ")
print()

for itsdaqVersion in noneJs:
        for js, jsNumber in noneJs[itsdaqVersion]:
            subtype = js["components"][0]["type"]["code"]
            noneSubtypes.append(subtype)
            if subtype == 'R0H1':
                print(jsNumber, end=" ")
# Out:
# 206 13 17 139 115
# 65 220 16 31 47 157 86 151 186

# %%
list(set(okSubtypes)), list(set(noneSubtypes))
# Out:
# (['R0H0',
#   'R4H0',
#   'R1H0',
#   'R0H1',
#   'R5H0',
#   'R4H1',
#   'R1H1',
#   'R3H1',
#   'R2H0',
#   'R5H1',
#   'R3H0'],
#  ['R3H2', 'R3H3', 'R1H0', 'R0H1'])

# %%
keys = jsons[206].keys()
for key in keys:
    if key == "results":
        continue
    print(key)
    print(jsons[13][key])
    print(jsons[186][key])
    print()
# Out:
# id
# 62d21e3de5e122000a6466e3
# 63c6126d3f47660036fc2fad
#
# state
# ready
# ready
#
# date
# 2022-06-29T20:23:16.000Z
# 2023-01-13T15:59:43.000Z
#
# testType
# {'id': '6203775e987fb9000ab4f245', 'code': 'RESPONSE_CURVE_PPA', 'name': 'Response Curve PPA', 'state': 'active'}
# {'id': '6203775e987fb9000ab4f245', 'code': 'RESPONSE_CURVE_PPA', 'name': 'Response Curve PPA', 'state': 'active'}
#
# institution
# {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}
# {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}
#
# user
# {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}
# {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}
#
# runNumber
# 670-8
# 442-8
#
# passed
# True
# False
#
# problems
# False
# False
#
# properties
# [{'code': 'DCS', 'name': 'DCS info', 'dataType': 'object', 'valueType': 'single', 'required': False, 'value': {'ABC_temp_raw_0': 2368, 'ABC_temp_raw_1': 2354, 'ABC_temp_raw_2': 2371, 'ABC_temp_raw_3': 2335, 'ABC_temp_raw_4': 2399, 'ABC_temp_raw_5': 2347, 'ABC_temp_raw_6': 2332, 'ABC_temp_raw_7': 2461, 'ABC_temp_raw_8': 2524, 'HCC_temp_raw': 343}, 'rangeMin': None, 'rangeMax': None}, {'code': 'det_info', 'name': 'det info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'ABC_Fuse': ['8940881c', '8940881d', '8940881e', '8940881f', '89408820', '89408821', '89408819', '89408818', '89408816'], 'Address': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'Channel': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'DUT_type': 'ABCStar_Test', 'HCC_Fuse': '304008b9', 'name': 'ABCStar_R0H1_Hybrid2'}, 'rangeMin': None, 'rangeMax': None}, {'code': 'fit_type_code', 'name': 'fit type code', 'dataType': 'integer', 'valueType': 'single', 'required': True, 'value': 3, 'rangeMin': None, 'rangeMax': None}, {'code': 'scan_info', 'name': 'scan info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'event_count': 1024, 'points': [0.19200000166893005, 0.4993000030517578, 0.8059999942779541, 0.9980000257492065, 1.2669999599456787, 1.496899962425232, 1.996000051498413, 2.993000030517578, 3.990999937057495, 5.985000133514404], 'type': 'QCAL (fC)'}, 'rangeMin': None, 'rangeMax': None}, {'code': 'special_point_index', 'name': 'special point index', 'dataType': 'integer', 'valueType': 'single', 'required': True, 'value': 5, 'rangeMin': None, 'rangeMax': None}, {'code': 'system_info', 'name': 'system info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'Analysis_time': '2022-06-29T20:23:19.000Z', 'Firmware revision': '0xb60f', 'GIT URL': 'https://gitlab.cern.ch/atlas-itk-strips-daq/itsdaq-sw.git/-/tree/2e483864c9e049b94337f6a68d4fcb89bf05ce0d', 'GIT branch': '', 'GIT build date': '2022-05-25 16:19:06 +0000 (Wed, 25 May 2022)', 'GIT commit date': '2022-05-24 14:47:21 +0000 (Tue, 24 May 2022)', 'GIT describe': 'itsdaq_24_1_2022-438-g2e48386', 'GIT revision': '2e483864c9e049b94337f6a68d4fcb89bf05ce0d', 'Location': 'Celestica', 'User': 'CEL', 'analysis_version': '3.43', 'dedication': "New dedication as we're going for PPA", 'host': 'hybridpanel'}, 'rangeMin': None, 'rangeMax': None}]
# [{'code': 'DCS', 'name': 'DCS info', 'dataType': 'object', 'valueType': 'single', 'required': False, 'value': {'ABC_temp_raw_10': 2478, 'ABC_temp_raw_2': 2465, 'ABC_temp_raw_3': 2478, 'ABC_temp_raw_4': 2509, 'ABC_temp_raw_5': 2548, 'ABC_temp_raw_6': 2600, 'ABC_temp_raw_7': 2459, 'ABC_temp_raw_8': 2519, 'ABC_temp_raw_9': 2522, 'HCC_temp_raw': 403}, 'rangeMin': None, 'rangeMax': None}, {'code': 'det_info', 'name': 'det info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'ABC_Fuse': [None, None, '89406911', '89406912', '89406913', '8940690b', '8940690a', '89406909', '89406908', '89406907', '89406906'], 'Address': [None, None, 8, 7, 6, 5, 4, 3, 2, 1, 0], 'Channel': [None, None, 2, 3, 4, 5, 6, 7, 8, 9, 10], 'DUT_type': 'ABCStar_Test', 'HCC_Fuse': '30007208', 'name': 'ABCStar_R0H1_Hybrid1'}, 'rangeMin': None, 'rangeMax': None}, {'code': 'fit_type_code', 'name': 'fit type code', 'dataType': 'integer', 'valueType': 'single', 'required': True, 'value': 3, 'rangeMin': None, 'rangeMax': None}, {'code': 'scan_info', 'name': 'scan info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'event_count': 1024, 'points': [0.19200000166893005, 0.4993000030517578, 0.8059999942779541, 0.9980000257492065, 1.2669999599456787, 1.496899962425232, 1.996000051498413, 2.993000030517578, 3.990999937057495, 5.985000133514404], 'type': 'QCAL (fC)'}, 'rangeMin': None, 'rangeMax': None}, {'code': 'special_point_index', 'name': 'special point index', 'dataType': 'integer', 'valueType': 'single', 'required': True, 'value': 5, 'rangeMin': None, 'rangeMax': None}, {'code': 'system_info', 'name': 'system info', 'dataType': 'object', 'valueType': 'single', 'required': True, 'value': {'Analysis_time': '2023-01-13T15:59:45.000Z', 'Firmware revision': '0xb5fb', 'GIT URL': 'https://gitlab.cern.ch/atlas-itk-strips-daq/itsdaq-sw.git/-/tree/967d1cd0f31599de02ca6f0f2ac3f7a848de86a4', 'GIT branch': 'HEAD', 'GIT build date': '2023-01-13 15:28:40 +0000 (Fri, 13 Jan 2023)', 'GIT commit date': '2023-01-06 17:40:56 +0000 (Fri, 06 Jan 2023)', 'GIT describe': 'itsdaq_28_6_2022-369-g967d1cd', 'GIT revision': '967d1cd0f31599de02ca6f0f2ac3f7a848de86a4', 'Location': 'CEL', 'User': 'CEL', 'analysis_version': '3.43', 'dedication': "New dedication as we're going for PPA", 'host': 'celesticamodule'}, 'rangeMin': None, 'rangeMax': None}]
#
# cts
# 2022-07-16T02:11:09.845Z
# 2023-01-17T03:13:49.385Z
#
# sys
# {'cts': '2022-07-16T02:11:09.845Z', 'mts': '2022-07-16T02:11:09.845Z', 'rev': 0}
# {'cts': '2023-01-17T03:13:49.385Z', 'mts': '2023-01-17T03:13:49.385Z', 'rev': 0}
#
# defects
# []
# [{'code': 'f2e16f3139d4f1a132e84f68', 'name': 'HI_GAIN', 'description': 'Strip with high gain', 'properties': []}, {'code': 'acfeb35a5befc4f1559a3be6', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '9fa19dabf7d0334c66c5a222', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '460db1c44b6947c9fdec69a8', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '9d80b722b7ad87d45724db5e', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': 'ae4b0a8ea491dce9a09e59f7', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '90d367646406accc7edd6be4', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '9594f3948ae67a89bb392f88', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '5d8430c7f837dc64423cd35f', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': 'c2747439b2c59c7ee3281707', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '0f3913fe2d580c5fc2ec3773', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '603ca269cda63b2f00eea177', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '923985bcb2249d1632fa6d80', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '2249a7720dc94fe59596b925', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '9f56b1caed1c27f7b0a92279', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': 'fd46b65351127254d0cf3130', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': '09f380dab4d16e6bba6a4cb6', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': 'e9656e2489aa76aa697099b0', 'name': 'NOISY', 'description': 'Strip with high noise', 'properties': []}, {'code': 'b6ca802656e7b281cb20413f', 'name': 'HI_GAIN', 'description': 'Strip with high gain', 'properties': []}, {'code': 'da31adcc62e3079eb265bb07', 'name': 'VLO_GAIN', 'description': 'Very low gain', 'properties': []}]
#
# comments
# None
# [{'code': '8fd57e971cad4e83f77303b1', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': '20 defects found affecting 26 strips', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': 'f5e20edf780631b015787cbc', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': '4 maximum consecutive defects', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': '934389fd043dd945e0457cdb', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'Chip 10 (away) fit range adjusted (0.0fC - 1.3fC) from 6.0fC', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': '1ae621f568547006c0b388d4', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'FAIL due to chip 6 (under) noise sigma (> 25.000000)', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': '97e27f84a07c28da3c1b7c5a', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'FAIL due to chip 7 (under) noise sigma (> 25.000000)', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': 'a749e3ae42bca94f534fc14d', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'FAIL due to chip 10 (under) noise sigma (> 25.000000)', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': '3cdb266592f6852141c2dc60', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'FAIL due to chip 10 (away) very low gain (< 55.000000)', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}, {'code': '62f2fee01f65d88e2fbcaedf', 'dateTime': '2023-01-17T03:13:49.376Z', 'comment': 'FAIL due to 26 bad strips (more than 15)', 'user': {'id': '618ac9cafd67f3000a6c728c', 'userIdentity': '5979-5851-1', 'firstName': 'Jia', 'middleName': '', 'lastName': 'Jian Teoh'}}]
#
# attachments
# []
# []
#
# components
# [{'id': '62ab90e9e684f9000abe788c', 'code': '323171ff489e700032fc9423257b1aec', 'state': 'ready', 'stateTs': '2022-06-16T20:22:01.445Z', 'stateUserIdentity': '4009-147-1', 'dummy': False, 'completed': True, 'completedTs': '2023-02-24T11:24:06.023Z', 'completedUserIdentity': '6777-7595-1', 'trashed': False, 'trashedTs': None, 'serialNumber': '20USEH10000058', 'alternativeIdentifier': 'CEL-R0H1-0003', 'project': {'code': 'S', 'name': 'Strips'}, 'subproject': {'code': 'SE', 'name': 'Strip endcaps'}, 'componentType': {'code': 'HYBRID_ASSEMBLY', 'name': 'STAR Hybrid Assembly'}, 'type': {'code': 'R0H1', 'name': 'R0H1 Assembly'}, 'properties': [{'code': 'PICK_AND_PLACE_MACHINE', 'name': 'Pick and Place Machine', 'dataType': 'boolean', 'required': False, 'default': False, 'value': True}, {'code': 'HYBRID_NAME', 'name': 'Hybrid Name', 'dataType': 'string', 'required': False, 'default': True, 'value': 'CEL-R0H1-0003'}], 'testedAtStage': {'code': 'WIRE_BONDING', 'name': 'Wire Bonding', 'order': 2, 'initial': False, 'final': False}, 'institution': {'code': 'CEL', 'name': 'Celestica'}}]
# [{'id': '618959052aaf09000a0ee4b5', 'code': '925ab1ca7c6e47ae0ce31a09e47ab0bf', 'state': 'ready', 'stateTs': '2021-11-08T17:06:13.351Z', 'stateUserIdentity': '643-7439-1', 'dummy': False, 'completed': True, 'completedTs': '2022-07-12T18:43:32.856Z', 'completedUserIdentity': '3804-6864-1', 'trashed': False, 'trashedTs': None, 'serialNumber': '20USEH10000031', 'alternativeIdentifier': 'UT-R0H1-0012', 'project': {'code': 'S', 'name': 'Strips'}, 'subproject': {'code': 'SE', 'name': 'Strip endcaps'}, 'componentType': {'code': 'HYBRID_ASSEMBLY', 'name': 'STAR Hybrid Assembly'}, 'type': {'code': 'R0H1', 'name': 'R0H1 Assembly'}, 'properties': [{'code': 'ASSEMBLY_JIG', 'name': 'Jig for ASIC assembly', 'dataType': 'string', 'required': False, 'default': False, 'value': None}, {'code': 'GLUE_SYRINGE', 'name': 'Glue Syringe', 'dataType': 'string', 'required': False, 'default': False, 'value': '20USEGL0000033'}, {'code': 'LOCAL_NAME', 'name': 'Local Name', 'dataType': 'string', 'required': False, 'default': False, 'value': 'Celestica R0H1 -8'}, {'code': 'ASSEMBLY_CHIPTRAY', 'name': 'Chip Tray for ASIC assembly', 'dataType': 'string', 'required': False, 'default': False, 'value': None}, {'code': 'ASSEMBLY_PICKUP_TOOL', 'name': 'Pick-Up Tool for ASIC assembly', 'dataType': 'string', 'required': False, 'default': False, 'value': None}, {'code': 'PICK_AND_PLACE_MACHINE', 'name': 'Pick and Place Machine', 'dataType': 'boolean', 'required': False, 'default': False, 'value': True}, {'code': 'HYBRID_NAME', 'name': 'Hybrid Name', 'dataType': 'string', 'required': False, 'default': True, 'value': 'UT-R0H1-0012'}], 'testedAtStage': {'code': 'ON_MODULE', 'name': 'On Module', 'order': 8, 'initial': False, 'final': True}, 'institution': {'code': 'UT', 'name': 'University of Toronto'}}]

# %%
print(okJs['2023-02-19'][0][1], noneJs['2023-02-19'][0][1]
# Out:
# 12 83

# %%
files[206], files[65]
# Out:
# ('../../data/627bdf5fba163f000ab8032f.json',
#  '../../data/62f558a78bb668000a1bc0f3.json')

# %%
js[]

# %%
fig = plt.figure(figsize=(12, 8))
variable = "innse_away"
for key in componentInfo:
    points = componentInfo[key][variable][0]
    if isinstance(points, list):
        nPoints = len(points)
        plt.scatter([componentInfo[key]["subtype"]]*nPoints, componentInfo[key][variable][0])
ax = plt.gca()
xticklabels = ax.get_xticklabels()
ax.set_xticklabels(xticklabels, rotation = 90);
#plt.axhline(400, *ax.get_xlim(), linestyle=":")
plt.grid()
# Out:
# /tmp/ipykernel_20982/2135482256.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels, rotation = 90);

# %%
for component in componentInfo:
    print(component, componentInfo[component]["count"], componentInfo[component]["subtype"])
# Out:
# 20USEH50000014 1 R3H0
# 20USEH80000011 2 R3H3
# 20USEH30000025 1 R1H1
# 20USEH40000027 6 R2H0
# 20USEH40000024 4 R2H0
# 20USEH30000012 1 R1H1
# 20USEH40000059 4 R2H0
# 20USEH60000010 2 R3H1
# 20USEH90000029 2 R4H0
# 20USEHB0000027 1 R5H0
# 20USEH20000015 1 R1H0
# 20USEH70000009 2 R3H2
# 20USEH00000208 1 R0H0
# 20USEH90000035 1 R4H0
# 20USEH20000026 1 R1H0
# 20USEH20000028 2 R1H0
# 20USEH50000013 2 R3H0
# 20USEH20000032 2 R1H0
# 20USEHA0000030 2 R4H1
# 20USEH10000031 2 R0H1
# 20USEH80000010 1 R3H3
# 20USEH00000210 1 R0H0
# 20USEH30000020 1 R1H1
# 20USEH90000027 1 R4H0
# 20USEH40000057 2 R2H0
# 20USEHB0000026 1 R5H0
# 20USEH10000029 1 R0H1
# 20USEH60000012 1 R3H1
# 20USEH30000024 1 R1H1
# 20USEHC0000012 1 R5H1
# 20USEH90000026 1 R4H0
# 20USEHA0000044 1 R4H1
# 20USEH30000022 1 R1H1
# 20USEH40000056 2 R2H0
# 20USEH90000042 1 R4H0
# 20USEHA0000033 1 R4H1
# 20USEH20000033 1 R1H0
# 20USEHA0000043 1 R4H1
# 20USEH40000026 5 R2H0
# 20USEHA0000039 1 R4H1
# 20USEH70000010 1 R3H2
# 20USEH30000021 1 R1H1
# 20USEH40000025 1 R2H0
# 20USEH20000038 1 R1H0
# 20USEH00000217 1 R0H0
# 20USEHB0000014 1 R5H0
# 20USEH10000030 1 R0H1
# 20USEHC0000023 1 R5H1
# 20USEH90000040 1 R4H0
# 20USEHA0000028 1 R4H1
# 20USEH30000019 1 R1H1
# 20USEH20000027 1 R1H0
# 20USEHA0000029 1 R4H1
# 20USEHA0000032 1 R4H1
# 20USEHA0000038 1 R4H1
# 20USEH90000036 1 R4H0
# 20USEH00000209 2 R0H0
# 20USEH90000030 1 R4H0
# 20USEH20000034 1 R1H0
# 20USEH10000036 1 R0H1
# 20USEH90000039 1 R4H0
# 20USEH00000211 1 R0H0
# 20USEHC0000026 1 R5H1
# 20USEH10000032 1 R0H1
# 20USEHB0000028 1 R5H0
# 20USEHC0000025 1 R5H1

# %%
subtypeCounts = {}
for subtype in subtypes:
    subtypeCounts[subtype] = [0, 0];
    for component in componentInfo:
        if componentInfo[component]["subtype"] == subtype:
            subtypeCounts[subtype][0] += 1
            subtypeCounts[subtype][1] += componentInfo[component]["count"]

# %%
print("{head1:>8} {mod:>8} {tests:>6}".format(head1="Subtype", mod="#modules", tests="#tests"))
subtypeCounts["SSX"] = ["?", 9]
subtypeCounts["SSY"] = ["?", 8]
subtypeCounts["LSX"] = ["?", 12]
for subtype in subtypes:
    print("{head1:>8} {mod:>8} {tests:>6}".format(head1=subtype, mod=subtypeCounts[subtype][0], tests=subtypeCounts[subtype][1]))
# Out:
#  Subtype #modules #tests
#     R0H0        5      6
#     R0H1        5      6
#     R1H0        8     10
#     R1H1        7      7
#     R2H0        7     24
#     R3H0        2      3
#     R3H1        2      3
#     R3H2        2      3
#     R3H3        2      3
#     R4H0        9     10
#     R4H1        9     10
#     R5H0        4      4
#     R5H1        4      4
#      SSX        ?      9
#      SSY        ?      8
#      LSX        ?     12
#      LSY        0      0

# %%
Number of SSX hybrids: 9
Number of SSY hybrids: 8
Number of LSX hybrids: 12
Number of LSY hybrids: 0

# %%
import sys
sys.path.append("../../parsers/")
from RCparsers import parseRC

# %%
hybrid = parseRC("../../data/63c6126d3f47660036fc2fad.json")
# Out:
# Parsing file: ../../data/63c6126d3f47660036fc2fad.json
# Addresses [None, None, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
import json

# %%
with open("../../data/63c6126d3f47660036fc2fad.json", 'r') as f:
    data = json.load(f)

# %%
hej = ["62f5568c8bb668000a1bbdff", "62f556868bb668000a1bbdd9", "63c611ef3ae21f0036ca3653", "62c58bf8e684f9000a0b8f63", "627bdd03ba163f000ab8002c", "627bdd07ba163f000ab80057", "62f558488bb668000a1bc024", "63c611f63f47660036fc2da7", "62f5584e8bb668000a1bc048"]

# %%
len(hej)
# Out:
# 9

# %%
len(files)
# Out:
# 315

# %%
moduleIDfiles = glob.glob("../Helpers/jsonFiles/*.json")

# %%
subtypeFileCount = {}
for file in moduleIDfiles:
    with open(file, "r") as f:
        js = json.load(f)
    subtype = file.split("/")[-1].strip("data.json")
    subtypeFileCount[subtype] = len(js["bonded_itkdb_testids"])

# %%
subtypeFileCount
# Out:
# {'R1H0': 10,
#  'R4H1': 8,
#  'R3H3': 4,
#  'R3H1': 4,
#  'R5H0': 0,
#  'R5H1': 0,
#  'R0H0': 9,
#  'R3H0': 4,
#  'R4H0': 8,
#  'R0H1': 13,
#  'R2H0': 34,
#  'R3H2': 4,
#  'R1H1': 10}
