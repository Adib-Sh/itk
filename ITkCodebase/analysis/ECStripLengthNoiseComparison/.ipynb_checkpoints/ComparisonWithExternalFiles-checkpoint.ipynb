# %%
from ECStripLengthNoiseComparison import ECStripLengthNoiseComparison
import glob
import json
import fnmatch

subtypes = []
allBarrelSubtypes = ["SSX", "SSY", "LSX", "LSY"]
with open("../Helpers/subtypes.txt", 'r') as f:
    allECSubtypes = f.read().split(',')
allSubtypes = []
allSubtypes.extend(allECSubtypes)
allSubtypes.extend(allBarrelSubtypes)
subtypes = allSubtypes

# %%
dataPath = "../../../data/fromLuise/"
files = glob.glob(dataPath + "**/*RESPONSE_CURVE_PPA.json", recursive=True)

# %%
jsons = []
for file in files:
    with open(file, "r") as f:
        jsons.append(json.load(f))

# %%
import sys
sys.path.append("../../")
from parsers.RCparsers import parseRC
import matplotlib.pyplot as plt
import numpy as np

# %%
hybrids = {}
for f, file in enumerate(files):
    split = file.split("_")
    subtype = fnmatch.filter(split, "R?H?")
    if subtype:
        subtype = subtype[0]
        if subtype not in hybrids.keys():
            hybrids[subtype] = []
        hybrids[subtype].append(parseRC(file, verbose=False))
subtypes = list(hybrids.keys())

# %%
fig, axs = plt.subplots(len(subtypes), figsize=(8, 12))
streamName = {0 : "under", 1 : "away"}
for ax, subtype in zip(axs, subtypes):
    for stream in [0, 1]:
        innses = []
        for hybrid in hybrids[subtype]:
            innses.extend([channel.innse for channel in hybrid.getStream(stream)])
        ax.hist(innses, bins=np.linspace(0, 1800, 100),
                label=subtype+" "+streamName[stream]+" ("+str(len(hybrids[subtype]))+" tests)")
    ax.legend()

# %%
def findKey(dct, targetKey):
    if isinstance(dct, dict):
        for key in dct.keys():
            if key == targetKey:
                print(dct[key])
            elif key in targetKey or targetKey in key:
                print("Partial key match;", key, dct[key])
            else:
                findKey(dct[key], targetKey)
    print()

# %%
for js in jsons:
    findKey(js, "testedAtStage")

# %%
js.keys()
# Out:
# dict_keys(['comments', 'date', 'defects', 'passed', 'problems', 'properties', 'results', 'runNumber', 'testType'])

# %%
for key in js:
    print(js[key] if key != "results" else None)
# Out:
# ['12 defects found affecting 13 strips', '2 maximum consecutive defects', 'FAIL due to chip 4 (under) noise sigma (> 25.000000)', 'FAIL due to chip 5 (under) noise sigma (> 25.000000)']
# 2023-01-26T21:29:05.000Z
# [{'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 0, 'chip_bank': 'under', 'chip_in_histo': 0}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 596, 'chip_bank': 'under', 'chip_in_histo': 4}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 598, 'chip_bank': 'under', 'chip_in_histo': 4}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel_from': 601, 'channel_to': 602, 'chip_bank': 'under', 'chip_in_histo': 4}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 609, 'chip_bank': 'under', 'chip_in_histo': 4}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 651, 'chip_bank': 'under', 'chip_in_histo': 5}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 655, 'chip_bank': 'under', 'chip_in_histo': 5}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 732, 'chip_bank': 'under', 'chip_in_histo': 5}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 743, 'chip_bank': 'under', 'chip_in_histo': 5}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 1023, 'chip_bank': 'under', 'chip_in_histo': 7}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 0, 'chip_bank': 'away', 'chip_in_histo': 0}}, {'description': 'Strip with high noise', 'name': 'NOISY', 'properties': {'channel': 1023, 'chip_bank': 'away', 'chip_in_histo': 7}}]
# True
# False
# {'DCS': {'ABC_temp_raw_10': 2588.0, 'ABC_temp_raw_3': 2471.0, 'ABC_temp_raw_4': 2442.0, 'ABC_temp_raw_5': 2405.0, 'ABC_temp_raw_6': 2534.0, 'ABC_temp_raw_7': 2471.0, 'ABC_temp_raw_8': 2526.0, 'ABC_temp_raw_9': 2514.0, 'HCC_temp_raw': 450.0, 'Module 0_current': 292.0, 'Module 0_voltage': 4500.0}, 'det_info': {'ABC_Fuse': ['894088d2', '894088d1', '89409013', '89409012', '89409011', '89409010', '8940900d', '8940900c'], 'Address': [3, 4, 5, 6, 7, 8, 9, 10], 'Channel': [3, 4, 5, 6, 7, 8, 9, 10], 'DUT_type': 'ABCStar_Test #3y #corrct mappin', 'HCC_Fuse': '20400915', 'name': 'DENNIS_PPB_ABCStar_R4H1_Hybrid0'}, 'fit_type_code': 4, 'scan_info': {'event_count': 1024, 'points': [0.4993000030517578, 0.9980000257492065, 1.496899962425232], 'type': 'QCAL (fC)'}, 'special_point_index': 1, 'system_info': {'Analysis_time': '2023-01-26T21:29:08.000Z', 'Firmware revision': '0xb60f', 'GIT URL': 'https://gitlab.cern.ch/atlas-itk-strips-daq/itsdaq-sw.git/-/tree/cad999901cbc004acfbc86b48fd2dece853eb852', 'GIT branch': '', 'GIT build date': '2022-12-09 17:38:59 +0000 (Fri, 09 Dec 2022)', 'GIT commit date': '2022-12-09 11:00:29 +0000 (Fri, 09 Dec 2022)', 'GIT describe': 'itsdaq_28_6_2022-368-gcad9999', 'GIT revision': 'cad999901cbc004acfbc86b48fd2dece853eb852', 'Location': 'TRIUMF', 'User': 'LP', 'analysis_version': '3.43', 'dedication': "New dedication as we're going for PPA", 'host': 'rockbiter'}}
# None
# 2614-3
# RESPONSE_CURVE_PPA

# %%
files
# Out:
# ['../../../data/fromLuise/M20/SN20USEHA0000044_20230126_2633_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/SN20USEHA0000044_20230126_2633_9_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2626_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/SN20USEH90000039_20230126_2633_9_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2626_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2626_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/SN20USEH90000039_20230126_2633_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M20/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2626_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000013/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20221209_2255_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000013/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20221209_2255_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000013/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20221209_2255_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000013/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20221209_2255_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000012/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20221209_2257_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000012/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20221209_2257_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000012/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20221209_2257_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000012/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20221209_2257_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000011/PPB_ABCStar_R1H1_Hybrid0_20221121_2049_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000011/PPB_ABCStar_R1H0_Hybrid1_20221121_2049_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000011/PPB_ABCStar_R1H1_Hybrid0_20221121_2049_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000011/PPB_ABCStar_R1H0_Hybrid1_20221121_2049_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000010/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20230104_2378_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000010/DENNIS_PPB_ABCStar_R1H0_Hybrid1_20230104_2378_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000010/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20230104_2378_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/20USEM1000001/20USEM10000010/DENNIS_PPB_ABCStar_R1H1_Hybrid0_20230104_2378_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEHA0000038_20230126_2623_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2620_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEHA0000038_20230126_2622_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEHA0000038_20230126_2622_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEHA0000038_20230126_2623_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2620_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEH90000035_20230126_2622_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2620_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEH90000035_20230126_2623_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2620_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEH90000035_20230126_2622_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M19/SN20USEH90000035_20230126_2623_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEHA0000032_20230126_2616_5_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2614_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEHA0000032_20230126_2617_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2614_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEH90000040_20230126_2616_8_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEH90000040_20230126_2617_3_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEH90000040_20230126_2616_5_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEHA0000032_20230126_2616_8_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEH90000040_20230126_2617_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/DENNIS_PPB_ABCStar_R4H0_Hybrid1_20230126_2614_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/SN20USEHA0000032_20230126_2617_6_RESPONSE_CURVE_PPA.json',
#  '../../../data/fromLuise/M18/DENNIS_PPB_ABCStar_R4H1_Hybrid0_20230126_2614_3_RESPONSE_CURVE_PPA.json']

# %%
import itkdb
user = itkdb.core.User(accessCode1="", accessCode2="")
user.authenticate()
client = itkdb.Client(user=user)

# %%
SNs = []
for file in files:
    sn = None
    parts = file.split("/")
    for part in parts:
        subparts = part.split("_")
        for subpart in subparts:
            if "20USE" in subpart:
                sn = subpart
                break
    if sn:
        if sn[:2] == "SN":
            sn = sn[2:]
        SNs.append(sn)
print("Number of files:", len(files))
print("Number of SNs gathered:", len(SNs))
# Out:
# Number of files: 48
# Number of SNs gathered: 36

# %%
components = []
for sn in SNs:
    try:
        component = client.get("getComponent", json={"component":sn})
    except Exception as exception:
        print("Component", sn, "not found. Exception raised:", exception)
    components.append(component)

# %%
component = client.get('getComponent', json = {'component':'20USEHA0000044'})

# %%
components[0]
# Out:
# {'id': '62fbcde02d8fbc000ac5614f',
#  'code': '6e5d5a4aed42ad902b0df66cae8011b4',
#  'serialNumber': '20USEHA0000044',
#  'alternativeIdentifier': 'UT-R4H1-0032',
#  'project': {'code': 'S', 'name': 'Strips'},
#  'subproject': {'code': 'SE', 'name': 'Strip endcaps'},
#  'institution': {'id': '5ac66e2609d7a800067a4cb4',
#   'code': 'UT',
#   'name': 'University of Toronto',
#   'latitude': 43.667713,
#   'longitude': -79.396688},
#  'currentLocation': {'id': '5e559114da03b1000ac8ca33',
#   'code': 'UBC',
#   'name': 'Vancouver UBC',
#   'latitude': 49.266692,
#   'longitude': -123.252231},
#  'currentLocationTs': '2023-02-22T05:03:45.100Z',
#  'currentLocationUserIdentity': '22-1535-1',
#  'shipmentDestination': None,
#  'user': {'id': '622286ca80e95c000a4ede99',
#   'userIdentity': '8296-6169-1',
#   'firstName': 'Ewan',
#   'middleName': '',
#   'lastName': 'Chin Hill'},
#  'componentType': {'id': '600175bae4caf8000a50ce77',
#   'code': 'HYBRID_ASSEMBLY',
#   'name': 'STAR Hybrid Assembly',
#   'snAutomatically': True,
#   'category': 'assembly',
#   'state': 'active'},
#  'type': {'code': 'R4H1', 'name': 'R4H1 Assembly'},
#  'currentStage': {'code': 'ON_MODULE',
#   'name': 'On Module',
#   'order': 8,
#   'initial': False,
#   'final': True,
#   'testTypes': [{'testType': '61b0a6b93be1da000a90c899',
#     'nextStage': False,
#     'order': 1,
#     'receptionTest': None,
#     'receptionTestOnly': None,
#     'notification': None,
#     'reminderInterval': None},
#    {'testType': '620386ea987fb9000ab51fac',
#     'nextStage': False,
#     'order': 2,
#     'receptionTest': None,
#     'receptionTestOnly': None,
#     'notification': None,
#     'reminderInterval': None},
#    {'testType': '6203775e987fb9000ab4f245',
#     'nextStage': False,
#     'order': 3,
#     'receptionTest': None,
#     'receptionTestOnly': None,
#     'notification': None,
#     'reminderInterval': None},
#    {'testType': '61b1cc253be1da000a91b20f',
#     'nextStage': False,
#     'order': 4,
#     'receptionTest': None,
#     'receptionTestOnly': None,
#     'notification': None,
#     'reminderInterval': None}]},
#  'properties': [{'code': 'PICK_AND_PLACE_MACHINE',
#    'name': 'Pick and Place Machine',
#    'value': True,
#    'dateTime': '2022-08-16T17:03:28.470Z',
#    'userIdentity': '8296-6169-1',
#    'dataType': 'boolean',
#    'required': False,
#    'default': False},
#   {'code': 'HYBRID_NAME',
#    'name': 'Hybrid Name',
#    'value': 'UT-R4H1-0032',
#    'dateTime': '2022-08-16T17:03:34.581Z',
#    'userIdentity': '8296-6169-1',
#    'dataType': 'string',
#    'required': False,
#    'default': True},
#   {'code': 'LOCAL_NAME',
#    'name': 'Local Name',
#    'dataType': 'string',
#    'required': False,
#    'default': False,
#    'value': None,
#    'dateTime': None,
#    'userIdentity': None},
#   {'code': 'ASSEMBLY_PICKUP_TOOL',
#    'name': 'Pick-Up Tool for ASIC assembly',
#    'dataType': 'string',
#    'required': False,
#    'default': False,
#    'value': None,
#    'dateTime': None,
#    'userIdentity': None},
#   {'code': 'ASSEMBLY_JIG',
#    'name': 'Jig for ASIC assembly',
#    'dataType': 'string',
#    'required': False,
#    'default': False,
#    'value': None,
#    'dateTime': None,
#    'userIdentity': None},
#   {'code': 'ASSEMBLY_CHIPTRAY',
#    'name': 'Chip Tray for ASIC assembly',
#    'dataType': 'string',
#    'required': False,
#    'default': False,
#    'value': None,
#    'dateTime': None,
#    'userIdentity': None},
#   {'code': 'GLUE_SYRINGE',
#    'name': 'Glue Syringe',
#    'dataType': 'string',
#    'required': False,
#    'default': False,
#    'value': None,
#    'dateTime': None,
#    'userIdentity': None}],
#  'children': [{'id': '13976b0ae813275e82bac49657bc9aa4',
#    'order': 0,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d6084fed67730005160cd4',
#     'code': 'HCC',
#     'name': 'HCC Chip',
#     'category': 'item'},
#    'type': {'code': 'HCCSTAR', 'name': 'HCCSTAR'},
#    'component': None,
#    'properties': [{'code': 'HCC_POSITION',
#      'value': None,
#      'name': 'HCC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITON_ON_WAFER',
#      'value': None,
#      'name': 'Positon on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False},
#     {'code': 'FUSE_ID',
#      'value': None,
#      'name': 'Fuse ID',
#      'default': False,
#      'dataType': 'string',
#      'required': False}]},
#   {'id': '9a1ff7a6e2e8c0350c344783e418271f',
#    'order': 1,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d6084fed67730005160cd4',
#     'code': 'HCC',
#     'name': 'HCC Chip',
#     'category': 'item'},
#    'type': {'code': 'HCCSTAR', 'name': 'HCCSTAR'},
#    'component': None,
#    'properties': [{'code': 'HCC_POSITION',
#      'value': None,
#      'name': 'HCC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITON_ON_WAFER',
#      'value': None,
#      'name': 'Positon on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False},
#     {'code': 'FUSE_ID',
#      'value': None,
#      'name': 'Fuse ID',
#      'default': False,
#      'dataType': 'string',
#      'required': False}]},
#   {'id': '299d34668c7d5b5ce38127ea106b4846',
#    'order': 0,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': '19ce5babf70ea16d3c166a176e466610',
#    'order': 1,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': '673c6097023f49d53766b154a13e37c6',
#    'order': 2,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': '5e46d45c114b152b83b07961c3a7538f',
#    'order': 3,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': 'df3c0dcc43842ec0215a9a22e79512ba',
#    'order': 4,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': 'c5ed9461416f16a3450f41cf5bb47b0c',
#    'order': 5,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': '1eb8c29eab22b0a51baa9ed4761070bd',
#    'order': 6,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': '5f1ca12729e7e49700031554a19fe017',
#    'order': 7,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:28.495Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTAR', 'name': 'ABCSTAR'},
#    'component': None,
#    'properties': [{'code': 'ABC_POSITION',
#      'value': None,
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': None,
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': None,
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}]},
#   {'id': 'b6bdd704ead56715916f7966d9e95763',
#    'order': 0,
#    'state': 'ready',
#    'timestamp': '2022-08-16T17:03:31.760Z',
#    'identity': '8296-6169-1',
#    'componentType': {'id': '5e18419d4334b6000aaf338a',
#     'code': 'HYBRID_FLEX',
#     'name': 'STAR Hybrid Flex',
#     'category': 'item'},
#    'type': {'code': 'R4H1', 'name': 'R4H1'},
#    'component': {'id': '61c0418c3be1da000a9cbc90',
#     'code': 'ff0f388bd4d5bc6b28bb77ce762c0f7d',
#     'serialNumber': '20USEHN0000238',
#     'state': 'ready',
#     'stateTs': '2021-12-20T08:40:43.986Z',
#     'stateUserIdentity': '6698-5894-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'alternativeIdentifier': 'L001-N1_R4H1_P3.1_B_H1'},
#    'history': [{'action': 'assembly',
#      'component': {'id': '61c0418c3be1da000a9cbc90',
#       'code': 'ff0f388bd4d5bc6b28bb77ce762c0f7d',
#       'serialNumber': '20USEHN0000238',
#       'state': 'ready',
#       'stateTs': '2021-12-20T08:40:43.986Z',
#       'stateUserIdentity': '6698-5894-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'alternativeIdentifier': 'L001-N1_R4H1_P3.1_B_H1',
#       'timestamp': '2022-08-16T17:03:31.760Z'},
#      'identity': {'id': '622286ca80e95c000a4ede99',
#       'userIdentity': '8296-6169-1',
#       'firstName': 'Ewan',
#       'middleName': '',
#       'lastName': 'Chin Hill'},
#      'componentType': {'id': '5e18419d4334b6000aaf338a',
#       'code': 'HYBRID_FLEX',
#       'name': 'STAR Hybrid Flex',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'R4H1', 'name': 'R4H1'}}]},
#   {'id': '55e40858077e7bb9c9680dc85a4ea6b4',
#    'order': 0,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:38:55.453Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d6084fed67730005160cd4',
#     'code': 'HCC',
#     'name': 'HCC Chip',
#     'category': 'item'},
#    'type': {'code': 'HCCSTARV1', 'name': 'HCCSTARV1'},
#    'component': {'id': '621eaf5d80e95c000a3fdc50',
#     'code': 'f054b770b1d56b162b32ae427d80f450',
#     'serialNumber': '20USGAH1001246',
#     'state': 'ready',
#     'stateTs': '2022-03-01T23:42:21.956Z',
#     'stateUserIdentity': '3275-4053-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'HCC4008f6'},
#    'properties': [{'code': 'HCC_POSITION',
#      'value': 'HCC_R4H1_2',
#      'dateTime': '2022-09-25T19:38:55.453Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'HCC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'V0D97AH',
#      'dateTime': '2022-09-25T19:38:55.453Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 246,
#      'dateTime': '2022-09-25T19:38:55.453Z',
#      'userIdentity': '5979-5851-1'},
#     {'code': 'FUSE_ID',
#      'value': '4008F6',
#      'dateTime': '2022-09-25T19:38:55.453Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Fuse ID',
#      'default': False,
#      'dataType': 'string',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '621eaf5d80e95c000a3fdc50',
#       'code': 'f054b770b1d56b162b32ae427d80f450',
#       'serialNumber': '20USGAH1001246',
#       'state': 'ready',
#       'stateTs': '2022-03-01T23:42:21.956Z',
#       'stateUserIdentity': '3275-4053-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'HCC4008f6',
#       'timestamp': '2022-09-25T19:38:55.453Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d6084fed67730005160cd4',
#       'code': 'HCC',
#       'name': 'HCC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'HCCSTARV1', 'name': 'HCCStarv1'},
#      'properties': [{'code': 'HCC_POSITION',
#        'value': 'HCC_R4H1_2',
#        'dateTime': '2022-09-25T19:38:55.453Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'HCC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'V0D97AH',
#        'dateTime': '2022-09-25T19:38:55.453Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 246,
#        'dateTime': '2022-09-25T19:38:55.453Z',
#        'userIdentity': '5979-5851-1'},
#       {'code': 'FUSE_ID',
#        'value': '4008F6',
#        'dateTime': '2022-09-25T19:38:55.453Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Fuse ID',
#        'default': False,
#        'dataType': 'string',
#        'required': False}]}]},
#   {'id': 'b70c1fd930d196978825f527ded82a8d',
#    'order': 1,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:38:57.684Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d6084fed67730005160cd4',
#     'code': 'HCC',
#     'name': 'HCC Chip',
#     'category': 'item'},
#    'type': {'code': 'HCCSTARV1', 'name': 'HCCSTARV1'},
#    'component': {'id': '621eaf5e80e95c000a3fdc52',
#     'code': '7a92364d5649ad895fc8949ccf141553',
#     'serialNumber': '20USGAH1001247',
#     'state': 'ready',
#     'stateTs': '2022-03-01T23:42:22.456Z',
#     'stateUserIdentity': '3275-4053-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'HCC4008f7'},
#    'properties': [{'code': 'HCC_POSITION',
#      'value': 'HCC_R4H1_3',
#      'dateTime': '2022-09-25T19:38:57.684Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'HCC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'V0D97AH',
#      'dateTime': '2022-09-25T19:38:57.684Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 247,
#      'dateTime': '2022-09-25T19:38:57.684Z',
#      'userIdentity': '5979-5851-1'},
#     {'code': 'FUSE_ID',
#      'value': '4008F7',
#      'dateTime': '2022-09-25T19:38:57.684Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Fuse ID',
#      'default': False,
#      'dataType': 'string',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '621eaf5e80e95c000a3fdc52',
#       'code': '7a92364d5649ad895fc8949ccf141553',
#       'serialNumber': '20USGAH1001247',
#       'state': 'ready',
#       'stateTs': '2022-03-01T23:42:22.456Z',
#       'stateUserIdentity': '3275-4053-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'HCC4008f7',
#       'timestamp': '2022-09-25T19:38:57.684Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d6084fed67730005160cd4',
#       'code': 'HCC',
#       'name': 'HCC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'HCCSTARV1', 'name': 'HCCStarv1'},
#      'properties': [{'code': 'HCC_POSITION',
#        'value': 'HCC_R4H1_3',
#        'dateTime': '2022-09-25T19:38:57.684Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'HCC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'V0D97AH',
#        'dateTime': '2022-09-25T19:38:57.684Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 247,
#        'dateTime': '2022-09-25T19:38:57.684Z',
#        'userIdentity': '5979-5851-1'},
#       {'code': 'FUSE_ID',
#        'value': '4008F7',
#        'dateTime': '2022-09-25T19:38:57.684Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Fuse ID',
#        'default': False,
#        'dataType': 'string',
#        'required': False}]}]},
#   {'id': '41e424fa738a40b0196d7bc1f4622965',
#    'order': 0,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:00.612Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb0b3be1da000aab511d',
#     'code': '03464678dfefab889260b1c404724039',
#     'serialNumber': '20USGAA1018239',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:22:03.352Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090ef'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_3',
#      'dateTime': '2022-09-25T19:39:00.612Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:00.612Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 239,
#      'dateTime': '2022-09-25T19:39:00.612Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb0b3be1da000aab511d',
#       'code': '03464678dfefab889260b1c404724039',
#       'serialNumber': '20USGAA1018239',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:22:03.352Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090ef',
#       'timestamp': '2022-09-25T19:39:00.612Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_3',
#        'dateTime': '2022-09-25T19:39:00.612Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:00.612Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 239,
#        'dateTime': '2022-09-25T19:39:00.612Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': '7541b7a3c21a27f3a7d84e5e965b0d96',
#    'order': 1,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:02.644Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb093be1da000aab5107',
#     'code': 'ff7249e2810a0a63de01f01aa0c562d0',
#     'serialNumber': '20USGAA1018238',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:22:01.706Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090ee'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_4',
#      'dateTime': '2022-09-25T19:39:02.644Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:02.644Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 238,
#      'dateTime': '2022-09-25T19:39:02.644Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb093be1da000aab5107',
#       'code': 'ff7249e2810a0a63de01f01aa0c562d0',
#       'serialNumber': '20USGAA1018238',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:22:01.706Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090ee',
#       'timestamp': '2022-09-25T19:39:02.644Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_4',
#        'dateTime': '2022-09-25T19:39:02.644Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:02.644Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 238,
#        'dateTime': '2022-09-25T19:39:02.644Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': '7f42ffb67b4053819845a6c6c8ba70cb',
#    'order': 2,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:04.574Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb063be1da000aab50ea',
#     'code': '6aa72e20452144264a3b408c1744ce05',
#     'serialNumber': '20USGAA1018237',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:21:58.766Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090ed'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_5',
#      'dateTime': '2022-09-25T19:39:04.574Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:04.574Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 237,
#      'dateTime': '2022-09-25T19:39:04.574Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb063be1da000aab50ea',
#       'code': '6aa72e20452144264a3b408c1744ce05',
#       'serialNumber': '20USGAA1018237',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:21:58.766Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090ed',
#       'timestamp': '2022-09-25T19:39:04.574Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_5',
#        'dateTime': '2022-09-25T19:39:04.574Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:04.574Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 237,
#        'dateTime': '2022-09-25T19:39:04.574Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': '934d1eecf830baa6f6224fbde742f996',
#    'order': 3,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:06.751Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb033be1da000aab50d4',
#     'code': '3bbff4882c90b139e33143e49bf35285',
#     'serialNumber': '20USGAA1018236',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:21:55.124Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090ec'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_6',
#      'dateTime': '2022-09-25T19:39:06.751Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:06.751Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 236,
#      'dateTime': '2022-09-25T19:39:06.751Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb033be1da000aab50d4',
#       'code': '3bbff4882c90b139e33143e49bf35285',
#       'serialNumber': '20USGAA1018236',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:21:55.124Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090ec',
#       'timestamp': '2022-09-25T19:39:06.751Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_6',
#        'dateTime': '2022-09-25T19:39:06.751Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:06.751Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 236,
#        'dateTime': '2022-09-25T19:39:06.751Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': 'aa918f33959242f598c0cf61b0632db5',
#    'order': 4,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:08.713Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb013be1da000aab50be',
#     'code': 'bb48fb016ec82c47287e0865cb6f3334',
#     'serialNumber': '20USGAA1018235',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:21:53.917Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090eb'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_7',
#      'dateTime': '2022-09-25T19:39:08.713Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:08.713Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 235,
#      'dateTime': '2022-09-25T19:39:08.713Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb013be1da000aab50be',
#       'code': 'bb48fb016ec82c47287e0865cb6f3334',
#       'serialNumber': '20USGAA1018235',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:21:53.917Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090eb',
#       'timestamp': '2022-09-25T19:39:08.713Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_7',
#        'dateTime': '2022-09-25T19:39:08.713Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:08.713Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 235,
#        'dateTime': '2022-09-25T19:39:08.713Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': 'ffc9fcb7994eaca88ac5714c91da8d67',
#    'order': 5,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:10.741Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb003be1da000aab50a3',
#     'code': '45fd0b4e867e3795dd2c6b9fe7713969',
#     'serialNumber': '20USGAA1018234',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:21:52.394Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090ea'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_8',
#      'dateTime': '2022-09-25T19:39:10.741Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:10.741Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 234,
#      'dateTime': '2022-09-25T19:39:10.741Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb003be1da000aab50a3',
#       'code': '45fd0b4e867e3795dd2c6b9fe7713969',
#       'serialNumber': '20USGAA1018234',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:21:52.394Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090ea',
#       'timestamp': '2022-09-25T19:39:10.741Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_8',
#        'dateTime': '2022-09-25T19:39:10.741Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:10.741Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 234,
#        'dateTime': '2022-09-25T19:39:10.741Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': 'cbeb47bf1bb523d758d2641139ebecf3',
#    'order': 6,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:12.734Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb103be1da000aab5162',
#     'code': '41410cc55391931499e10dea93cea59b',
#     'serialNumber': '20USGAA1018242',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:22:08.545Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090f2'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_9',
#      'dateTime': '2022-09-25T19:39:12.734Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:12.734Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 242,
#      'dateTime': '2022-09-25T19:39:12.734Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb103be1da000aab5162',
#       'code': '41410cc55391931499e10dea93cea59b',
#       'serialNumber': '20USGAA1018242',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:22:08.545Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090f2',
#       'timestamp': '2022-09-25T19:39:12.734Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_9',
#        'dateTime': '2022-09-25T19:39:12.734Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:12.734Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 242,
#        'dateTime': '2022-09-25T19:39:12.734Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]},
#   {'id': 'e14f31ba60d09c94148fbf1e858b13a1',
#    'order': 7,
#    'state': 'ready',
#    'timestamp': '2022-09-25T19:39:14.327Z',
#    'identity': '5979-5851-1',
#    'componentType': {'id': '59d5f213ed67730005160cd3',
#     'code': 'ABC',
#     'name': 'ABC Chip',
#     'category': 'item'},
#    'type': {'code': 'ABCSTARV1', 'name': 'ABCSTARV1'},
#    'component': {'id': '61d6fb133be1da000aab517e',
#     'code': '03f99411bd49ae5e99b2cde607f8fa2e',
#     'serialNumber': '20USGAA1018243',
#     'state': 'ready',
#     'stateTs': '2022-01-06T14:22:11.136Z',
#     'stateUserIdentity': '24-4336-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'alternativeIdentifier': 'ABC4090f3'},
#    'properties': [{'code': 'ABC_POSITION',
#      'value': 'ABC_R4H1_10',
#      'dateTime': '2022-09-25T19:39:14.327Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'ABC Position',
#      'default': False,
#      'dataType': 'string',
#      'required': True},
#     {'code': 'WAFER_NUMBER',
#      'value': 'VTD2RXH',
#      'dateTime': '2022-09-25T19:39:14.327Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Wafer Number',
#      'default': False,
#      'dataType': 'string',
#      'required': False},
#     {'code': 'POSITION_ON_WAFER',
#      'value': 243,
#      'dateTime': '2022-09-25T19:39:14.327Z',
#      'userIdentity': '5979-5851-1',
#      'name': 'Position on Wafer',
#      'default': False,
#      'dataType': 'integer',
#      'required': False}],
#    'history': [{'action': 'assembly',
#      'component': {'id': '61d6fb133be1da000aab517e',
#       'code': '03f99411bd49ae5e99b2cde607f8fa2e',
#       'serialNumber': '20USGAA1018243',
#       'state': 'ready',
#       'stateTs': '2022-01-06T14:22:11.136Z',
#       'stateUserIdentity': '24-4336-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'ABC4090f3',
#       'timestamp': '2022-09-25T19:39:14.327Z'},
#      'identity': {'id': '618ac9cafd67f3000a6c728c',
#       'userIdentity': '5979-5851-1',
#       'firstName': 'Jia',
#       'middleName': '',
#       'lastName': 'Jian Teoh'},
#      'componentType': {'id': '59d5f213ed67730005160cd3',
#       'code': 'ABC',
#       'name': 'ABC Chip',
#       'category': 'item',
#       'state': 'active'},
#      'type': {'code': 'ABCSTARV1', 'name': 'ABCStarv1'},
#      'properties': [{'code': 'ABC_POSITION',
#        'value': 'ABC_R4H1_10',
#        'dateTime': '2022-09-25T19:39:14.327Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'ABC Position',
#        'default': False,
#        'dataType': 'string',
#        'required': True},
#       {'code': 'WAFER_NUMBER',
#        'value': 'VTD2RXH',
#        'dateTime': '2022-09-25T19:39:14.327Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Wafer Number',
#        'default': False,
#        'dataType': 'string',
#        'required': False},
#       {'code': 'POSITION_ON_WAFER',
#        'value': 243,
#        'dateTime': '2022-09-25T19:39:14.327Z',
#        'userIdentity': '5979-5851-1',
#        'name': 'Position on Wafer',
#        'default': False,
#        'dataType': 'integer',
#        'required': False}]}]}],
#  'parents': [{'id': 'eb7ebe8a3e7ea9aee3b781ed90770c5a',
#    'timestamp': None,
#    'identity': None,
#    'component': None,
#    'componentType': {'id': '60059690e4caf8000a510f9b',
#     'code': 'HYBRID_TEST_PANEL',
#     'name': 'STAR Hybrid Test Panel',
#     'category': 'reusable'},
#    'type': None,
#    'history': [{'action': 'assembly',
#      'component': {'id': '61dc6a973be1da000ab3a949',
#       'code': '71d6548c69680b41108cc21569a9a770',
#       'serialNumber': '20USET40000009',
#       'state': 'ready',
#       'stateTs': '2022-01-10T17:19:19.621Z',
#       'stateUserIdentity': '643-7439-1',
#       'dummy': False,
#       'completed': False,
#       'completedTs': None,
#       'completedUserIdentity': None,
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'UT-R4-PANEL-0116',
#       'timestamp': '2022-10-07T18:56:19.641Z'},
#      'identity': {'id': '633da0c3883f23000a1d3349',
#       'userIdentity': '6777-7595-1',
#       'firstName': 'Nikta',
#       'middleName': '',
#       'lastName': 'Zarif Yussefian'},
#      'componentType': {'id': '60059690e4caf8000a510f9b',
#       'code': 'HYBRID_TEST_PANEL',
#       'name': 'STAR Hybrid Test Panel',
#       'category': 'reusable',
#       'state': 'active'},
#      'type': {'code': 'R4', 'name': 'R4 Test Panel'},
#      'properties': [{'code': 'HYBRID_POSITION',
#        'value': '2',
#        'dateTime': '2022-10-07T18:56:19.641Z',
#        'userIdentity': '6777-7595-1'},
#       {'code': 'JIG_FOR_HYBRID_PLACEMENT',
#        'value': '20USERT0412005',
#        'dateTime': '2022-10-07T18:56:19.641Z',
#        'userIdentity': '6777-7595-1'},
#       {'code': 'PICKUPTOOL_FOR_HYBRID_PLACEMENT',
#        'value': '20USERT0431005',
#        'dateTime': '2022-10-07T18:56:19.641Z',
#        'userIdentity': '6777-7595-1'}]},
#     {'action': 'disassembly',
#      'component': {'id': '62fbcde02d8fbc000ac5614f',
#       'code': '6e5d5a4aed42ad902b0df66cae8011b4',
#       'serialNumber': '20USEHA0000044',
#       'state': 'ready',
#       'stateTs': '2022-08-16T17:03:28.470Z',
#       'stateUserIdentity': '8296-6169-1',
#       'dummy': False,
#       'completed': True,
#       'completedTs': '2023-01-17T23:11:13.586Z',
#       'completedUserIdentity': '822-5724-1',
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'UT-R4H1-0032',
#       'timestamp': '2023-01-17T23:11:45.359Z'},
#      'identity': {'id': '60b7f740d4b131000a66f607',
#       'userIdentity': '822-5724-1',
#       'firstName': 'Peter',
#       'middleName': '',
#       'lastName': 'Speers'},
#      'componentType': {'id': '600175bae4caf8000a50ce77',
#       'code': 'HYBRID_ASSEMBLY',
#       'name': 'STAR Hybrid Assembly',
#       'category': 'assembly',
#       'state': 'active'},
#      'type': {'code': 'R4H1', 'name': 'R4H1 Assembly'},
#      'properties': [{'code': 'HYBRID_POSITION',
#        'value': None,
#        'dateTime': '2023-01-17T23:11:45.359Z',
#        'userIdentity': '822-5724-1'},
#       {'code': 'JIG_FOR_HYBRID_PLACEMENT',
#        'value': None,
#        'dateTime': '2023-01-17T23:11:45.359Z',
#        'userIdentity': '822-5724-1'},
#       {'code': 'PICKUPTOOL_FOR_HYBRID_PLACEMENT',
#        'value': None,
#        'dateTime': '2023-01-17T23:11:45.359Z',
#        'userIdentity': '822-5724-1'}]}]},
#   {'id': '7e43693519ad31412e5a9bfd008f8701',
#    'timestamp': '2023-01-17T23:14:38.680Z',
#    'identity': '822-5724-1',
#    'component': {'id': '63a35d4c4f8219003670182e',
#     'code': 'f524b42611da67798a9f0985b85deafe',
#     'serialNumber': '20USE4L0000018',
#     'state': 'ready',
#     'stateTs': '2022-12-21T19:23:56.476Z',
#     'stateUserIdentity': '24-1239-1',
#     'dummy': False,
#     'completed': False,
#     'completedTs': None,
#     'completedUserIdentity': None,
#     'trashed': False,
#     'trashedTs': None,
#     'trashedUserIdentity': None,
#     'alternativeIdentifier': 'TRIUMF-R4M1_HALFMODULE-0011'},
#    'componentType': {'id': '59d60c13ed67730005160cd8',
#     'code': 'MODULE',
#     'name': 'Module',
#     'category': 'assembly'},
#    'type': None,
#    'history': [{'action': 'assembly',
#      'component': {'id': '62fbcde02d8fbc000ac5614f',
#       'code': '6e5d5a4aed42ad902b0df66cae8011b4',
#       'serialNumber': '20USEHA0000044',
#       'state': 'ready',
#       'stateTs': '2022-08-16T17:03:28.470Z',
#       'stateUserIdentity': '8296-6169-1',
#       'dummy': False,
#       'completed': True,
#       'completedTs': '2023-01-17T23:11:13.586Z',
#       'completedUserIdentity': '822-5724-1',
#       'trashed': False,
#       'trashedTs': None,
#       'alternativeIdentifier': 'UT-R4H1-0032',
#       'timestamp': '2023-01-17T23:14:38.680Z'},
#      'identity': {'id': '60b7f740d4b131000a66f607',
#       'userIdentity': '822-5724-1',
#       'firstName': 'Peter',
#       'middleName': '',
#       'lastName': 'Speers'},
#      'componentType': {'id': '600175bae4caf8000a50ce77',
#       'code': 'HYBRID_ASSEMBLY',
#       'name': 'STAR Hybrid Assembly',
#       'category': 'assembly',
#       'state': 'active'},
#      'type': {'code': 'R4H1', 'name': 'R4H1 Assembly'},
#      'properties': [{'code': 'JIG_HYBRID_ALIGNMENT',
#        'value': '20USERT0421006',
#        'dateTime': '2023-01-17T23:14:38.680Z',
#        'userIdentity': '822-5724-1'},
#       {'code': 'PICKUPTOOL_HYBRID',
#        'value': '20USERT0431014',
#        'dateTime': '2023-01-17T23:14:38.680Z',
#        'userIdentity': '822-5724-1'},
#       {'code': 'HYBRID_GLUE_SAMPLE',
#        'value': '2023.01.17 #1',
#        'dateTime': '2023-01-17T23:14:38.680Z',
#        'userIdentity': '822-5724-1'},
#       {'code': 'MODULE_ASSEMBLY_JIG',
#        'value': '20USERT0401014',
#        'dateTime': '2023-01-17T23:14:38.680Z',
#        'userIdentity': '822-5724-1'}]}]}],
#  'flags': None,
#  'stages': [{'code': 'ASIC_ATTACHMENT',
#    'dateTime': '2022-08-16T17:03:28.470Z',
#    'userIdentity': '8296-6169-1',
#    'rework': None,
#    'comment': None,
#    'name': 'ASIC Attachment'},
#   {'code': 'WIRE_BONDING',
#    'dateTime': '2022-09-29T17:23:53.004Z',
#    'userIdentity': '5979-5851-1',
#    'rework': None,
#    'comment': None,
#    'name': 'Wire Bonding'},
#   {'code': 'FINISHED_HYBRID',
#    'dateTime': '2022-09-29T17:44:59.193Z',
#    'userIdentity': '5979-5851-1',
#    'rework': None,
#    'comment': None,
#    'name': 'Finished Hybrid'},
#   {'code': 'WIRE_BONDING',
#    'dateTime': '2022-10-19T19:26:25.108Z',
#    'userIdentity': '6777-7595-1',
#    'rework': False,
#    'comment': None,
#    'name': 'Wire Bonding'},
#   {'code': 'FINISHED_HYBRID',
#    'dateTime': '2022-10-19T20:01:30.845Z',
#    'userIdentity': '6777-7595-1',
#    'rework': False,
#    'comment': None,
#    'name': 'Finished Hybrid'},
#   {'code': 'AT_MODULE_ASSEMBLY_SITE',
#    'dateTime': '2023-01-17T23:11:05.552Z',
#    'userIdentity': '822-5724-1',
#    'rework': False,
#    'comment': None,
#    'name': 'At Module Assembly Site'},
#   {'code': 'ON_MODULE',
#    'dateTime': '2023-01-17T23:11:13.586Z',
#    'userIdentity': '822-5724-1',
#    'rework': False,
#    'comment': None,
#    'name': 'On Module'}],
#  'locations': [{'institution': '5a83234ddaf1a000052e3e9f',
#    'dateTime': '2022-10-31T17:37:14.932Z',
#    'shipment': '634eb746fe669c001bfb1c69',
#    'stage': 'FINISHED_HYBRID'},
#   {'institution': '5e559114da03b1000ac8ca33',
#    'dateTime': '2023-02-22T05:03:45.100Z',
#    'shipment': '63d82f32afa0e600369bfd8d',
#    'stage': 'ON_MODULE'}],
#  'assembled': True,
#  'state': 'ready',
#  'stateTs': '2022-08-16T17:03:28.470Z',
#  'stateUserIdentity': '8296-6169-1',
#  'dummy': False,
#  'completed': True,
#  'completedTs': '2023-01-17T23:11:13.586Z',
#  'completedUserIdentity': '822-5724-1',
#  'completedReason': 'Automatically set',
#  'trashed': False,
#  'trashedTs': None,
#  'trashedUserIdentity': None,
#  'trashedReason': None,
#  'inTransit': None,
#  'inTransitTs': None,
#  'reworked': False,
#  'reworkedTs': None,
#  'reworkedUserIdentity': None,
#  'reworkedReason': None,
#  'qaPassed': None,
#  'qaState': None,
#  'currentGrade': None,
#  'currentGradeTs': None,
#  'currentGradeUserIdentity': None,
#  'currentGradeReason': None,
#  'grades': [],
#  'sys': {'cts': '2022-08-16T17:03:28.492Z',
#   'mts': '2023-02-22T05:03:49.200Z',
#   'rev': 40},
#  'scripts': {'registration': 'completed'},
#  'comments': None,
#  'tests': [{'id': '6034f0162d86a5000ada39e6',
#    'code': 'ASIC_GLUE_WEIGHT',
#    'name': 'Glue weight (ASICs on hybrid)',
#    'testRuns': [{'id': '62ffe0d6a55e67000b9b02ec',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '1',
#      'passed': True,
#      'problems': False,
#      'date': '2022-08-15T12:00:00.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-08-19T19:13:26.492Z'}]},
#   {'id': '60bcee913ef8d6000a0aa6e0',
#    'code': 'ASIC_METROLOGY',
#    'name': 'ASIC Metrology',
#    'testRuns': [{'id': '6333635cd0381d000a02e94a',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '    1',
#      'passed': False,
#      'problems': False,
#      'date': '2022-09-27T20:55:56.410Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-27T20:55:56.415Z'}]},
#   {'id': '61b0a6b93be1da000a90c899',
#    'code': 'NO_PPA',
#    'name': 'Noise Occupancy PPA',
#    'testRuns': [{'id': '638015b770e4de0028684e98',
#      'state': 'ready',
#      'stateTs': '2022-11-25T01:09:11.019Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2126-17',
#      'passed': False,
#      'problems': False,
#      'date': '2022-11-25T01:00:38.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2022-11-25T01:09:11.028Z'},
#     {'id': '63e1dc45b5aac1003677c4d8',
#      'state': 'ready',
#      'stateTs': '2023-02-07T05:06:13.606Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2633-19',
#      'passed': False,
#      'problems': False,
#      'date': '2023-01-27T00:46:52.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2023-02-07T05:06:13.709Z'},
#     {'id': '6335d816d0381d000a0569a6',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '827-18',
#      'passed': False,
#      'problems': False,
#      'date': '2022-09-23T21:25:19.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-29T17:38:30.550Z'}]},
#   {'id': '61b1cc253be1da000a91b20f',
#    'code': 'STROBE_DELAY_PPA',
#    'name': 'Strobe Delay PPA',
#    'testRuns': [{'id': '638015a770e4de0028684e45',
#      'state': 'ready',
#      'stateTs': '2022-11-25T01:08:55.555Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2126-3',
#      'passed': True,
#      'problems': False,
#      'date': '2022-11-25T00:55:39.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2022-11-25T01:08:55.562Z'},
#     {'id': '63e1dc326cd28a0036d3b416',
#      'state': 'ready',
#      'stateTs': '2023-02-07T05:05:54.609Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2633-5',
#      'passed': True,
#      'problems': True,
#      'date': '2023-01-27T00:36:31.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2023-02-07T05:05:54.682Z'},
#     {'id': '6335d80fd0381d000a056944',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '827-4',
#      'passed': True,
#      'problems': False,
#      'date': '2022-09-23T21:18:41.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-29T17:38:23.536Z'}]},
#   {'id': '6203775e987fb9000ab4f245',
#    'code': 'RESPONSE_CURVE_PPA',
#    'name': 'Response Curve PPA',
#    'testRuns': [{'id': '638015ac70e4de0028684e50',
#      'state': 'ready',
#      'stateTs': '2022-11-25T01:09:00.559Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2126-4',
#      'passed': True,
#      'problems': False,
#      'date': '2022-11-25T00:56:38.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2022-11-25T01:09:00.576Z'},
#     {'id': '638015b170e4de0028684e74',
#      'state': 'ready',
#      'stateTs': '2022-11-25T01:09:05.785Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2126-7',
#      'passed': True,
#      'problems': False,
#      'date': '2022-11-25T01:00:31.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2022-11-25T01:09:05.800Z'},
#     {'id': '63e1dc386cd28a0036d3b433',
#      'state': 'ready',
#      'stateTs': '2023-02-07T05:05:59.910Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2633-6',
#      'passed': False,
#      'problems': False,
#      'date': '2023-01-27T00:37:51.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2023-02-07T05:06:01.042Z'},
#     {'id': '63e1dc3eb5aac1003677c499',
#      'state': 'ready',
#      'stateTs': '2023-02-07T05:06:06.571Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2633-9',
#      'passed': True,
#      'problems': False,
#      'date': '2023-01-27T00:42:44.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2023-02-07T05:06:06.894Z'},
#     {'id': '6335d811d0381d000a056954',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '827-5',
#      'passed': True,
#      'problems': False,
#      'date': '2022-09-23T21:20:01.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-29T17:38:25.833Z'},
#     {'id': '6335d814d0381d000a05697e',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '827-8',
#      'passed': True,
#      'problems': False,
#      'date': '2022-09-23T21:25:08.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-29T17:38:28.378Z'}]},
#   {'id': '620386ea987fb9000ab51fac',
#    'code': 'PEDESTAL_TRIM_PPA',
#    'name': 'Pedestal Trim PPA',
#    'testRuns': [{'id': '638015a270e4de0028684e39',
#      'state': 'ready',
#      'stateTs': '2022-11-25T01:08:50.591Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2126-2',
#      'passed': True,
#      'problems': False,
#      'date': '2022-11-25T00:55:35.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2022-11-25T01:08:50.600Z'},
#     {'id': '63e1dc2db5aac1003677c443',
#      'state': 'ready',
#      'stateTs': '2023-02-07T05:05:49.559Z',
#      'stateUserIdentity': '22-1535-1',
#      'runNumber': '2633-4',
#      'passed': True,
#      'problems': False,
#      'date': '2023-01-27T00:36:25.000Z',
#      'institution': {'id': '5a83234ddaf1a000052e3e9f',
#       'code': 'TRIUMF',
#       'name': 'TRIUMF'},
#      'cts': '2023-02-07T05:05:49.688Z'},
#     {'id': '6335d80dd0381d000a056936',
#      'state': 'ready',
#      'stateTs': None,
#      'stateUserIdentity': None,
#      'runNumber': '827-3',
#      'passed': True,
#      'problems': False,
#      'date': '2022-09-23T21:18:33.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-09-29T17:38:21.576Z'}]},
#   {'id': '6104a1a56d2d8b000a00381f',
#    'code': 'WIRE_BONDING',
#    'name': 'Wire bonding',
#    'testRuns': [{'id': '63505295a8b2a1001b2c38e1',
#      'state': 'ready',
#      'stateTs': '2022-10-19T19:40:05.416Z',
#      'stateUserIdentity': '6777-7595-1',
#      'runNumber': '1',
#      'passed': True,
#      'problems': False,
#      'date': '2022-08-25T12:00:00.000Z',
#      'institution': {'id': '5ac66e2609d7a800067a4cb4',
#       'code': 'UT',
#       'name': 'University of Toronto'},
#      'cts': '2022-10-19T19:40:05.423Z'}]}],
#  'attachments': [],
#  'cts': '2022-08-16T17:03:28.492Z'}

# %%
component = components[0]
findKey(component, "test")
# Out:
# Partial key match; testTypes [{'testType': '61b0a6b93be1da000a90c899', 'nextStage': False, 'order': 1, 'receptionTest': None, 'receptionTestOnly': None, 'notification': None, 'reminderInterval': None}, {'testType': '620386ea987fb9000ab51fac', 'nextStage': False, 'order': 2, 'receptionTest': None, 'receptionTestOnly': None, 'notification': None, 'reminderInterval': None}, {'testType': '6203775e987fb9000ab4f245', 'nextStage': False, 'order': 3, 'receptionTest': None, 'receptionTestOnly': None, 'notification': None, 'reminderInterval': None}, {'testType': '61b1cc253be1da000a91b20f', 'nextStage': False, 'order': 4, 'receptionTest': None, 'receptionTestOnly': None, 'notification': None, 'reminderInterval': None}]
# Partial key match; tests [{'id': '6034f0162d86a5000ada39e6', 'code': 'ASIC_GLUE_WEIGHT', 'name': 'Glue weight (ASICs on hybrid)', 'testRuns': [{'id': '62ffe0d6a55e67000b9b02ec', 'state': 'ready', 'stateTs': None, 'stateUserIdentity': None, 'runNumber': '1', 'passed': True, 'problems': False, 'date': '2022-08-15T12:00:00.000Z', 'institution': {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}, 'cts': '2022-08-19T19:13:26.492Z'}]}, {'id': '60bcee913ef8d6000a0aa6e0', 'code': 'ASIC_METROLOGY', 'name': 'ASIC Metrology', 'testRuns': [{'id': '6333635cd0381d000a02e94a', 'state': 'ready', 'stateTs': None, 'stateUserIdentity': None, 'runNumber': '    1', 'passed': False, 'problems': False, 'date': '2022-09-27T20:55:56.410Z', 'institution': {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}, 'cts': '2022-09-27T20:55:56.415Z'}]}, {'id': '61b0a6b93be1da000a90c899', 'code': 'NO_PPA', 'name': 'Noise Occupancy PPA', 'testRuns': [{'id': '638015b770e4de0028684e98', 'state': 'ready', 'stateTs': '2022-11-25T01:09:11.019Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2126-17', 'passed': False, 'problems': False, 'date': '2022-11-25T01:00:38.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2022-11-25T01:09:11.028Z'}, {'id': '63e1dc45b5aac1003677c4d8', 'state': 'ready', 'stateTs': '2023-02-07T05:06:13.606Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2633-19', 'passed': False, 'problems': False, 'date': '2023-01-27T00:46:52.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2023-02-07T05:06:13.709Z'}, {'id': '6335d816d0381d000a0569a6', 'state': 'ready', 'stateTs': None, 'stateUserIdentity': None, 'runNumber': '827-18', 'passed': False, 'problems': False, 'date': '2022-09-23T21:25:19.000Z', 'institution': {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}, 'cts': '2022-09-29T17:38:30.550Z'}]}, {'id': '61b1cc253be1da000a91b20f', 'code': 'STROBE_DELAY_PPA', 'name': 'Strobe Delay PPA', 'testRuns': [{'id': '638015a770e4de0028684e45', 'state': 'ready', 'stateTs': '2022-11-25T01:08:55.555Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2126-3', 'passed': True, 'problems': False, 'date': '2022-11-25T00:55:39.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2022-11-25T01:08:55.562Z'}, {'id': '63e1dc326cd28a0036d3b416', 'state': 'ready', 'stateTs': '2023-02-07T05:05:54.609Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2633-5', 'passed': True, 'problems': True, 'date': '2023-01-27T00:36:31.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2023-02-07T05:05:54.682Z'}, {'id': '6335d80fd0381d000a056944', 'state': 'ready', 'stateTs': None, 'stateUserIdentity': None, 'runNumber': '827-4', 'passed': True, 'problems': False, 'date': '2022-09-23T21:18:41.000Z', 'institution': {'id': '5ac66e2609d7a800067a4cb4', 'code': 'UT', 'name': 'University of Toronto'}, 'cts': '2022-09-29T17:38:23.536Z'}]}, {'id': '6203775e987fb9000ab4f245', 'code': 'RESPONSE_CURVE_PPA', 'name': 'Response Curve PPA', 'testRuns': [{'id': '638015ac70e4de0028684e50', 'state': 'ready', 'stateTs': '2022-11-25T01:09:00.559Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2126-4', 'passed': True, 'problems': False, 'date': '2022-11-25T00:56:38.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2022-11-25T01:09:00.576Z'}, {'id': '638015b170e4de0028684e74', 'state': 'ready', 'stateTs': '2022-11-25T01:09:05.785Z', 'stateUserIdentity': '22-1535-1', 'runNumber': '2126-7', 'passed': True, 'problems': False, 'date': '2022-11-25T01:00:31.000Z', 'institution': {'id': '5a83234ddaf1a000052e3e9f', 'code': 'TRIUMF', 'name': 'TRIUMF'}, 'cts': '2022-11-25T01:09:05.800Z'}, {'id': '63e1dc386cd28a0036d3b433', 'state': 'ready', 'stateTs': '2023-02-07T05:05:59 ...

# %%
help(str.find)
# Out:
# Help on method_descriptor:
#
# find(...)
#     S.find(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.
